# %%
import importlib
import hw1

# %%
importlib.reload(hw1)
res = hw1.k_means()
# Out:
# center: tensor([[ 0.2911, -0.5545],
#         [ 0.1694, -0.0518]])
# cost: tensor(164.5332)
# center: tensor([[ 1.9163, -2.0952],
#         [-1.9143,  2.0540]])
# cost: tensor(9.1200)

# %%
import torch
a = torch.tensor([[3,1],[4,2]])
center = torch.tensor([[2],[5]])
torch.sum(a)
print(a)
print(center)
print(a-center)
print((a-center)**2)
print(torch.sum((a-center)**2))
# Out:
# tensor([[3, 1],
#         [4, 2]])
# tensor([[2],
#         [5]])
# tensor([[ 1, -1],
#         [-1, -3]])
# tensor([[1, 1],
#         [1, 9]])
# tensor(12)
