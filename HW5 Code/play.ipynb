# %%
import hw5
import hw5_utils as utl
import importlib
import torch

# %%
importlib.reload(hw5)
x,y = utl.xor_data()
c = None

# %%
def f(x,y):
    return torch.dot(x,y)
kernel = f
alpha1 = hw5.svm_solver(x, y, 0.1, 10000, kernel,c)
def pred_fn1(x_test):
    return hw5.svm_predictor(alpha1, x, y, x_test,kernel)

importlib.reload(utl)
utl.svm_contour(pred_fn1)

# %%
kernel = utl.poly(2)
alpha1 = hw5.svm_solver(x, y, 0.1, 10000, kernel,c)
def pred_fn1(x_test):
    return hw5.svm_predictor(alpha1, x, y, x_test,kernel)

importlib.reload(utl)
utl.svm_contour(pred_fn1)

# %%
kernel = utl.rbf(1)
alpha1 = hw5.svm_solver(x, y, 0.1, 10000, kernel,c)
def pred_fn1(x_test):
    return hw5.svm_predictor(alpha1, x, y, x_test,kernel)

importlib.reload(utl)
utl.svm_contour(pred_fn1)

# %%
kernel = utl.rbf(2)
alpha1 = hw5.svm_solver(x, y, 0.1, 10000, kernel,c)
def pred_fn1(x_test):
    return hw5.svm_predictor(alpha1, x, y, x_test,kernel)

importlib.reload(utl)
utl.svm_contour(pred_fn1)

# %%
kernel = utl.rbf(4)
alpha1 = hw5.svm_solver(x, y, 0.1, 10000, kernel,c)
def pred_fn1(x_test):
    return hw5.svm_predictor(alpha1, x, y, x_test,kernel)

importlib.reload(utl)
utl.svm_contour(pred_fn1)

# %%
importlib.reload(hw5)
hw5.logistic_vs_ols()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[437], line 2
#       1 importlib.reload(hw5)
# ----> 2 hw5.logistic_vs_ols()
#
# File c:\Users\ziyet\CS 446\HW5\hw5.py:156, in logistic_vs_ols()
#     151 '''
#     152 Returns:
#     153     Figure: the figure plotted with matplotlib
#     154 '''
#     155 X, Y = utils.load_logistic_data()
# --> 156 wl = logistic(X,Y,num_iter=100000000)
#     157 wo = linear_normal(X,Y)
#     159 x1,idx = torch.sort(X[:,0])
#
# File c:\Users\ziyet\CS 446\HW5\hw5.py:127, in logistic(X, Y, lrate, num_iter)
#     121 X_new = torch.cat([torch.ones(n,1), X], dim = 1)
#     123 for i in range(num_iter):
#     124     # R = 0
#     125     # for j in range(n):
#     126     #     R += Y[j] * X_new[j] * (1 - 1 / (1 + torch.exp(-Y[j] * X_new[j] @ w)))
# ...
