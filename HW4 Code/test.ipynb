# %%
import torch
import hw4
import hw4_utils as utils
import importlib
import matplotlib.pyplot as plt

# %%
importlib.reload(hw4)
hw4.plot_linear()

# %%
importlib.reload(hw4)
hw4.plot_poly()

# %%
importlib.reload(hw4)
hw4.poly_xor()
# Out:
# (tensor([ 0.0000e+00, -5.9605e-08, -5.9605e-08,  0.0000e+00]),
#  tensor([-1.0000, -1.0000,  1.0000,  1.0000]))

# %%
X,Y = utils.load_xor_data()
print(X)
print(Y)
# Out:
# tensor([[-1.,  1.],
#         [ 1., -1.],
#         [-1., -1.],
#         [ 1.,  1.]])
# tensor([-1., -1.,  1.,  1.])
